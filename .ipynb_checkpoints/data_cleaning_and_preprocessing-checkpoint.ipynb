# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('nova_data.csv')

# %%
df.sample(5)
# Out:
#         nutriscore_score nutriscore_grade  nova_group  ecoscore_grade  \
# 82965               16.0                d         NaN               d
# 107870               0.0                b         4.0  not-applicable
# 11786                0.0                b         4.0               b
# 158368              14.0                d         4.0         unknown
# 186800              14.0                d         4.0               b
#
#             main_category_en  energy-kcal_100g  energy_100g   fat_100g  \
# 82965        Salad dressings        266.666667       1116.0  23.333333
# 107870  Diet cola soft drink          0.000000          0.0   0.000000
# 11786               Tomatoes         17.000000         71.0   0.000000
# 158368               Seafood        196.000000        820.0  10.710000
# 186800           Jelly beans        350.000000       1464.0   0.000000
#
#         saturated-fat_100g  cholesterol_100g  carbohydrates_100g  sugars_100g  \
# ...

# %% [markdown]
# # Understand the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227266 entries, 0 to 227265
# Data columns (total 19 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   nutriscore_score                                       187559 non-null  float64
#  1   nutriscore_grade                                       227266 non-null  object
#  2   nova_group                                             184582 non-null  float64
#  3   ecoscore_grade                                         227266 non-null  object
#  4   main_category_en                                       198371 non-null  object
#  5   energy-kcal_100g                                       226340 non-null  float64
#  6   energy_100g                                            226818 non-null  float64
#  7   fat_100g                                               227151 non-null  float64
# ...

# %%
df.describe()
# Out:
#        nutriscore_score     nova_group  energy-kcal_100g    energy_100g  \
# count     187559.000000  184582.000000     226340.000000  226818.000000
# mean           8.922600       3.504079        266.563050    1114.719633
# std            8.904543       0.934377        211.935905     886.943789
# min          -15.000000       1.000000          0.000000       0.000000
# 25%            1.000000       3.000000         90.000000     377.000000
# 50%           10.000000       4.000000        263.000000    1100.000000
# 75%           15.000000       4.000000        395.000000    1653.000000
# max           40.000000       4.000000      30000.000000  125520.000000
#
#             fat_100g  saturated-fat_100g  cholesterol_100g  \
# count  227151.000000       208362.000000     227266.000000
# mean       12.162232            4.472758          0.022321
# std        41.295780            8.095851          0.736425
# min         0.000000            0.000000          0.000000
# ...

# %% [markdown]
# # Remove unwanted columns based on the domain knowledge

# %%
df.columns
# Out:
# Index(['nutriscore_score', 'nutriscore_grade', 'nova_group', 'ecoscore_grade',
#        'main_category_en', 'energy-kcal_100g', 'energy_100g', 'fat_100g',
#        'saturated-fat_100g', 'cholesterol_100g', 'carbohydrates_100g',
#        'sugars_100g', 'fiber_100g', 'proteins_100g', 'salt_100g',
#        'sodium_100g', 'fruits-vegetables-nuts-estimate-from-ingredients_100g',
#        'nutrition-score-fr_100g', 'completion_rate'],
#       dtype='object')

# %%
df.drop(columns =['nutrition-score-fr_100g', 'completion_rate','fruits-vegetables-nuts-estimate-from-ingredients_100g','ecoscore_grade'], axis = 1, inplace =True)

# %%
df.drop(['main_category_en'], axis =1, inplace =True)

# %%
df.columns
# Out:
# Index(['nutriscore_score', 'nutriscore_grade', 'nova_group',
#        'energy-kcal_100g', 'energy_100g', 'fat_100g', 'saturated-fat_100g',
#        'cholesterol_100g', 'carbohydrates_100g', 'sugars_100g', 'fiber_100g',
#        'proteins_100g', 'salt_100g', 'sodium_100g'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#         nutriscore_score nutriscore_grade  nova_group  energy-kcal_100g  \
# 44672               -1.0                a         3.0              69.0
# 65991                5.0                c         4.0              84.0
# 135962               NaN          unknown         4.0               0.0
# 208923               NaN          unknown         NaN             321.0
# 11132               16.0                d         4.0             300.0
#
#         energy_100g  fat_100g  saturated-fat_100g  cholesterol_100g  \
# 44672         289.0      0.00                0.00               0.0
# 65991         351.0      2.26                1.61               0.0
# 135962          0.0      0.00                 NaN               0.0
# 208923       1343.0     14.00                0.00               0.0
# 11132        1255.0     20.00               10.00               0.1
#
#         carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# ...

# %%
print('the total number of the rows are:', df.shape[0])
print('the total number of the columns are:', df.shape[1])
# Out:
# the total number of the rows are: 227266
# the total number of the columns are: 14

# %%
df.sample(5)
# Out:
#         nutriscore_score nutriscore_grade  nova_group  energy-kcal_100g  \
# 20945               24.0                e         4.0             500.0
# 890                  NaN          unknown         NaN             388.0
# 220340              12.0                d         4.0             247.0
# 176521              14.0                d         4.0             200.0
# 72745                6.0                c         NaN             500.0
#
#         energy_100g  fat_100g  saturated-fat_100g  cholesterol_100g  \
# 20945        2092.0     26.92             15.3800             0.019
# 890          1623.0     29.00              3.0000             0.000
# 220340       1033.0     15.29              4.7100             0.047
# 176521        837.0     10.00              8.5700             0.029
# 72745        2092.0     25.00              3.5714             0.000
#
#         carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# ...

# %% [markdown]
# # check for nulll values

# %%
df['nova_group'].isnull().sum()
# Out:
# 42684

# %%
df['nova_group'].unique()
# Out:
# array([nan,  4.,  1.,  3.,  2.])

# %%
df['nova_group'].value_counts()
# Out:
# nova_group
# 4.0    132903
# 3.0     29465
# 1.0     17645
# 2.0      4569
# Name: count, dtype: int64

# %%
df['nutriscore_score'].isnull().sum()
# Out:
# 39707

# %%
df['nutriscore_score'].sample(4)
# Out:
# 166990    1.0
# 29995    -9.0
# 190988   -3.0
# 207925    7.0
# Name: nutriscore_score, dtype: float64

# %%
df.describe()
# Out:
#        nutriscore_score     nova_group  energy-kcal_100g    energy_100g  \
# count     187559.000000  184582.000000     226340.000000  226818.000000
# mean           8.922600       3.504079        266.563050    1114.719633
# std            8.904543       0.934377        211.935905     886.943789
# min          -15.000000       1.000000          0.000000       0.000000
# 25%            1.000000       3.000000         90.000000     377.000000
# 50%           10.000000       4.000000        263.000000    1100.000000
# 75%           15.000000       4.000000        395.000000    1653.000000
# max           40.000000       4.000000      30000.000000  125520.000000
#
#             fat_100g  saturated-fat_100g  cholesterol_100g  \
# count  227151.000000       208362.000000     227266.000000
# mean       12.162232            4.472758          0.022321
# std        41.295780            8.095851          0.736425
# min         0.000000            0.000000          0.000000
# ...

# %%
df.columns
# Out:
# Index(['nutriscore_score', 'nutriscore_grade', 'nova_group',
#        'energy-kcal_100g', 'energy_100g', 'fat_100g', 'saturated-fat_100g',
#        'cholesterol_100g', 'carbohydrates_100g', 'sugars_100g', 'fiber_100g',
#        'proteins_100g', 'salt_100g', 'sodium_100g'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# nutriscore_score      39707
# nutriscore_grade          0
# nova_group            42684
# energy-kcal_100g        926
# energy_100g             448
# fat_100g                115
# saturated-fat_100g    18904
# cholesterol_100g          0
# carbohydrates_100g      155
# sugars_100g            7084
# fiber_100g                0
# proteins_100g           236
# salt_100g              3954
# sodium_100g            3954
# dtype: int64

# %%
# rename some columns
df.rename(columns={'nutriscore_score': 'nutriscore'}, inplace=True)

# %%
df[df['nova_group']==1.0].sample(5)
# Out:
#         nutriscore nutriscore_grade  nova_group  energy-kcal_100g  \
# 106607        -4.0                a         1.0        357.142857
# 143293         4.0                c         1.0         46.000000
# 105220        -5.0                a         1.0        377.000000
# 110159         0.0                b         1.0         55.000000
# 175981       -13.0                a         1.0        133.000000
#
#         energy_100g  fat_100g  saturated-fat_100g  cholesterol_100g  \
# 106607       1494.0  1.785714                0.00             0.000
# 143293        192.0  0.000000                 NaN             0.000
# 105220       1577.0  1.890000                0.00             0.000
# 110159        230.0  2.120000                1.27             0.008
# 175981        556.0  0.600000                0.00             0.000
#
#         carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# ...

# %%
df[df['nutriscore_grade']=='a'].sample(5)
# Out:
#         nutriscore nutriscore_grade  nova_group  energy-kcal_100g  \
# 94094         -1.0                a         4.0        160.000000
# 194075        -1.0                a         4.0         35.000000
# 107199        -3.0                a         3.0        400.000000
# 4572          -3.0                a         3.0        160.000000
# 137627        -4.0                a         NaN        357.142857
#
#         energy_100g  fat_100g  saturated-fat_100g  cholesterol_100g  \
# 94094         669.0  4.000000                0.00             0.040
# 194075        146.0  0.000000                 NaN             0.000
# 107199       1674.0  3.330000                0.00             0.000
# 4572          669.0  1.250000                0.25             0.002
# 137627       1494.0  1.785714                0.00             0.000
#
#         carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# ...

# %%
df[df['nova_group']==1.0]['nutriscore'].mode()
# Out:
# 0   -4.0
# Name: nutriscore, dtype: float64

# %%
# Replace unknown or missing or any odd entries with null values

# %%
df['nutriscore_grade'].unique()
# Out:
# array(['a', 'd', 'unknown', 'b', 'c', 'e', 'not-applicable'], dtype=object)

# %%
df['nova_group'].unique()
# Out:
# array([nan,  4.,  1.,  3.,  2.])

# %%
df['nutriscore_grade'].replace(['unknown', 'missing', 'n/a','not-applicable'], np.nan, inplace=True)
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_8624\3019972790.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['nutriscore_grade'].replace(['unknown', 'missing', 'n/a','not-applicable'], np.nan, inplace=True)

# %% [markdown]
# # HANDLING MISSING DATA

# %% [markdown]
# ## Drop the rows which have nutriscore, nutriscore_grade and nova_group as null values

# %%
df.dropna(subset=['nutriscore', 'nutriscore_grade', 'nova_group'], how='all', inplace=True)
df
# Out:
#         nutriscore nutriscore_grade  nova_group  energy-kcal_100g  \
# 0             -5.0                a         NaN              57.0
# 1             18.0                d         NaN               NaN
# 2              9.0                d         NaN              63.0
# 3             -4.0                a         NaN              32.0
# 5              NaN              NaN         4.0             219.0
# ...            ...              ...         ...               ...
# 227261        13.0                d         NaN             286.0
# 227262         NaN              NaN         4.0             400.0
# 227263         NaN              NaN         2.0             286.0
# 227264         NaN              NaN         2.0             286.0
# 227265        13.0                d         2.0             286.0
#
#         energy_100g  fat_100g  saturated-fat_100g  cholesterol_100g  \
# 0             238.0       0.2                 0.1               0.0
# ...

# %% [markdown]
# # Interpolating the mode value for nutriscore null values based on some condition

# %%
df.loc[(df['nova_group'].isin([1.0])) & df['nutriscore_grade'].isin(['a','b'])]['nutriscore'].mode()
# Out:
# 0   -4.0
# Name: nutriscore, dtype: float64

# %%
df.loc[(df['nova_group'].isin([1.0,2.0]))]['nutriscore'].mode()
# Out:
# 0   -4.0
# Name: nutriscore, dtype: float64

# %%
df['nutriscore'].isnull().sum()
# Out:
# 21330

# %%
df['nova_group'].unique()
# Out:
# array([nan,  4.,  1.,  3.,  2.])

# %%
df[(df['nutriscore'].isnull()) & (df['nutriscore_grade'].isnull()) & (df['nova_group']== 1)]
# Out:
#         nutriscore nutriscore_grade  nova_group  energy-kcal_100g  \
# 41             NaN              NaN         1.0        333.000000
# 212            NaN              NaN         1.0        292.000000
# 214            NaN              NaN         1.0               NaN
# 229            NaN              NaN         1.0          0.000000
# 230            NaN              NaN         1.0          0.000000
# ...            ...              ...         ...               ...
# 224985         NaN              NaN         1.0        252.000000
# 225360         NaN              NaN         1.0          6.250000
# 225501         NaN              NaN         1.0         65.000000
# 226924         NaN              NaN         1.0         17.000000
# 226937         NaN              NaN         1.0         16.666667
#
#         energy_100g  fat_100g  saturated-fat_100g  cholesterol_100g  \
# 41           1393.0       NaN                 NaN              0.00
# ...

# %%
df[df['nova_group']==1.0]['nutriscore'].mode()
# Out:
# 0   -4.0
# Name: nutriscore, dtype: float64

# %%
df[df['nova_group']==2.0]['nutriscore'].mode()
# Out:
# 0    5.0
# Name: nutriscore, dtype: float64

# %%
df[df['nova_group']==3.0]['nutriscore'].mode()
# Out:
# 0    10.0
# Name: nutriscore, dtype: float64

# %%
df[df['nova_group']==4.0]['nutriscore'].mode()
# Out:
# 0    14.0
# Name: nutriscore, dtype: float64

# %%
df[df['nova_group']==3.0]['nutriscore_grade'].mode()
# Out:
# 0    d
# Name: nutriscore_grade, dtype: object

# %%
df.loc[(df['nutriscore'].isnull()) & (df['nutriscore_grade'].isnull()) & (df['nova_group']== 1.0), 'nutriscore']= -4.0
df.loc[(df['nutriscore'].isnull()) & (df['nutriscore_grade'].isnull()) & (df['nova_group']== 2.0), 'nutriscore'] = 5.0
df.loc[(df['nutriscore'].isnull()) & (df['nutriscore_grade'].isnull()) & (df['nova_group']== 1.0), 'nutriscore']= 10.0
df.loc[(df['nutriscore'].isnull()) & (df['nutriscore_grade'].isnull()) & (df['nova_group']== 2.0), 'nutriscore'] = 14.0

# %%
df
# Out:
#         nutriscore nutriscore_grade  nova_group  energy-kcal_100g  \
# 0             -5.0                a         NaN              57.0
# 1             18.0                d         NaN               NaN
# 2              9.0                d         NaN              63.0
# 3             -4.0                a         NaN              32.0
# 5              NaN              NaN         4.0             219.0
# ...            ...              ...         ...               ...
# 227261        13.0                d         NaN             286.0
# 227262         NaN              NaN         4.0             400.0
# 227263         5.0              NaN         2.0             286.0
# 227264         5.0              NaN         2.0             286.0
# 227265        13.0                d         2.0             286.0
#
#         energy_100g  fat_100g  saturated-fat_100g  cholesterol_100g  \
# 0             238.0       0.2                 0.1               0.0
# ...

# %% [markdown]
# # fill nova_group null values

# %%
df[(df['nutriscore'].isnull()) & (df['nutriscore_grade'].isnull()) & (df['nova_group']== 2.0)]
# Out:
# Empty DataFrame
# Columns: [nutriscore, nutriscore_grade, nova_group, energy-kcal_100g, energy_100g, fat_100g, saturated-fat_100g, cholesterol_100g, carbohydrates_100g, sugars_100g, fiber_100g, proteins_100g, salt_100g, sodium_100g]
# Index: []

# %%
df['nutriscore'].isnull().sum()
# Out:
# 20196

# %% [markdown]
# ## interpolate nutriscore value based on the nutriscore_grade and nova_group

# %%
df.loc[(df['nutriscore'].isnull())& (df['nutriscore_grade'].isnull()) & (df['nova_group']==3.0)]
# Out:
#         nutriscore nutriscore_grade  nova_group  energy-kcal_100g  \
# 284            NaN              NaN         3.0             250.0
# 310            NaN              NaN         3.0              69.0
# 385            NaN              NaN         3.0             100.0
# 480            NaN              NaN         3.0               NaN
# 576            NaN              NaN         3.0             167.0
# ...            ...              ...         ...               ...
# 225925         NaN              NaN         3.0             393.0
# 225961         NaN              NaN         3.0               NaN
# 226210         NaN              NaN         3.0             120.0
# 227043         NaN              NaN         3.0             167.0
# 227133         NaN              NaN         3.0             579.0
#
#         energy_100g   fat_100g  saturated-fat_100g  cholesterol_100g  \
# 284          1050.0   0.000000                 NaN             0.000
# ...

# %%
df.loc[
    (df['nova_group'] == 3.0) & 
    (df['nutriscore'].isna()) & 
    (df['nutriscore_grade'].isna()), 
    ['nutriscore', 'nutriscore_grade']
] = [9.0, 'c']
df
# Out:
#         nutriscore nutriscore_grade  nova_group  energy-kcal_100g  \
# 0             -5.0                a         NaN              57.0
# 1             18.0                d         NaN               NaN
# 2              9.0                d         NaN              63.0
# 3             -4.0                a         NaN              32.0
# 5              NaN              NaN         4.0             219.0
# ...            ...              ...         ...               ...
# 227261        13.0                d         NaN             286.0
# 227262         NaN              NaN         4.0             400.0
# 227263         5.0              NaN         2.0             286.0
# 227264         5.0              NaN         2.0             286.0
# 227265        13.0                d         2.0             286.0
#
#         energy_100g  fat_100g  saturated-fat_100g  cholesterol_100g  \
# 0             238.0       0.2                 0.1               0.0
# ...

# %%
df.loc[
    (df['nova_group'] == 4.0) & 
    (df['nutriscore'].isna()) & 
    (df['nutriscore_grade'].isna()), 
    ['nutriscore', 'nutriscore_grade']
] = [14, 'e']

# %%
df['nutriscore'].isnull().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['nutriscore', 'nutriscore_grade', 'nova_group', 'energy-kcal_100g',
#        'energy_100g', 'fat_100g', 'saturated-fat_100g', 'cholesterol_100g',
#        'carbohydrates_100g', 'sugars_100g', 'fiber_100g', 'proteins_100g',
#        'salt_100g', 'sodium_100g'],
#       dtype='object')

# %%
df['nutriscore_grade'].unique()
# Out:
# array(['a', 'd', 'e', 'b', 'c', nan], dtype=object)

# %%
df['nutriscore_grade'].value_counts()
# Out:
# nutriscore_grade
# d    58747
# e    53263
# c    37772
# a    31407
# b    26566
# Name: count, dtype: int64

# %% [markdown]
# # fill nutriscore null values based on the nova_score and nutriscore_grade

# %%
df.loc[(df['nutriscore'] <= 1.0) & (df['nutriscore_grade'].isin(['a']))]['nova_group'].mode()
# Out:
# 0    1.0
# Name: nova_group, dtype: float64

# %%
df.loc[df['nutriscore_grade']=='b', 'nova_group']=2.0

# %%
df[df['nutriscore_grade']=='b']['nova_group'].mode()
# Out:
# 0    2.0
# Name: nova_group, dtype: float64

# %%
df.loc[(df['nutriscore'] >= 5.0) & (df['nutriscore'] < 10.0) & (df['nutriscore_grade'].isin(['c']))]['nova_group'].mode()
# Out:
# 0    4.0
# Name: nova_group, dtype: float64

# %%
df.loc[
    (df['nutriscore'] <= 1.0) & 
    (df['nutriscore_grade'].isin(['a', 'b'])),
    'nova_group'] = 1.0

# %%
df.loc[
    (df['nutriscore'] >= 1) & 
    (df['nutriscore'] <= 5) & 
    (df['nutriscore_grade'].isin(['a', 'b','c'])), 
    'nova_group'
] = 2.0

# %%
df.loc[
    (df['nutriscore'] >= 5) & 
    (df['nutriscore'] <= 10) & 
    (df['nutriscore_grade'].isin(['b','c','d'])), 
    'nova_group'
] = 3.0

# %%
df.loc[
    (df['nutriscore'] >= 10) & 
    (df['nutriscore_grade'].isin(['d','e'])), 
    'nova_group'
] = 4.0

# %%
df['nova_group'].isnull().sum()
# Out:
# 0

# %%
df.nova_group.unique()
# Out:
# array([1., 4., 3., 2.])

# %%
df
# Out:
#         nutriscore nutriscore_grade  nova_group  energy-kcal_100g  \
# 0             -5.0                a         1.0              57.0
# 1             18.0                d         4.0               NaN
# 2              9.0                d         3.0              63.0
# 3             -4.0                a         1.0              32.0
# 5             14.0                e         4.0             219.0
# ...            ...              ...         ...               ...
# 227261        13.0                d         4.0             286.0
# 227262        14.0                e         4.0             400.0
# 227263         5.0              NaN         2.0             286.0
# 227264         5.0              NaN         2.0             286.0
# 227265        13.0                d         4.0             286.0
#
#         energy_100g  fat_100g  saturated-fat_100g  cholesterol_100g  \
# 0             238.0       0.2                 0.1               0.0
# ...

# %%
df.drop('nutriscore_grade', axis =1, inplace = True)

# %%
df
# Out:
#         nutriscore  nova_group  energy-kcal_100g  energy_100g  fat_100g  \
# 0             -5.0         1.0              57.0        238.0       0.2
# 1             18.0         4.0               NaN        936.0       8.2
# 2              9.0         3.0              63.0        264.0       0.0
# 3             -4.0         1.0              32.0        134.0       0.3
# 5             14.0         4.0             219.0        916.0       5.9
# ...            ...         ...               ...          ...       ...
# 227261        13.0         4.0             286.0       1197.0       0.0
# 227262        14.0         4.0             400.0       1674.0       0.0
# 227263         5.0         2.0             286.0       1197.0       0.0
# 227264         5.0         2.0             286.0       1197.0       0.0
# 227265        13.0         4.0             286.0       1197.0       0.0
#
#         saturated-fat_100g  cholesterol_100g  carbohydrates_100g  sugars_100g  \
# ...

# %%
df.columns
# Out:
# Index(['nutriscore', 'nova_group', 'energy-kcal_100g', 'energy_100g',
#        'fat_100g', 'saturated-fat_100g', 'cholesterol_100g',
#        'carbohydrates_100g', 'sugars_100g', 'fiber_100g', 'proteins_100g',
#        'salt_100g', 'sodium_100g'],
#       dtype='object')

# %%
df['energy-kcal_100g'].isnull().sum()
# Out:
# 849

# %%
df['energy_100g'].isnull().sum()
# Out:
# 397

# %% [markdown]
# # fill the null values of energy-kcal_100g

# %%
df.loc[df['energy-kcal_100g'].isnull()]
# Out:
#         nutriscore  nova_group  energy-kcal_100g  energy_100g  fat_100g  \
# 1             18.0         4.0               NaN        936.0      8.20
# 68             0.0         1.0               NaN        450.0      2.20
# 69             2.0         2.0               NaN        455.0      4.20
# 75             2.0         2.0               NaN       1952.4     15.30
# 146           26.0         4.0               NaN       2257.0     33.30
# ...            ...         ...               ...          ...       ...
# 226060        14.0         4.0               NaN          NaN     31.00
# 226284        24.0         4.0               NaN       2048.0     24.50
# 226769        14.0         4.0               NaN          NaN      0.00
# 227005         4.0         2.0               NaN        707.0      5.00
# 227015        12.0         4.0               NaN        784.0      6.43
#
#         saturated-fat_100g  cholesterol_100g  carbohydrates_100g  sugars_100g  \
# ...

# %% [markdown]
# ## Return all the rows which have energy-kcal null and energy-100g not null

# %%
df[(df['energy-kcal_100g'].isna()) & (df['energy_100g'].notna())]
# Out:
#         nutriscore  nova_group  energy-kcal_100g  energy_100g  fat_100g  \
# 1             18.0         4.0               NaN        936.0      8.20
# 68             0.0         1.0               NaN        450.0      2.20
# 69             2.0         2.0               NaN        455.0      4.20
# 75             2.0         2.0               NaN       1952.4     15.30
# 146           26.0         4.0               NaN       2257.0     33.30
# ...            ...         ...               ...          ...       ...
# 225912        14.0         4.0               NaN       1510.0     31.10
# 225966        14.0         4.0               NaN       1075.0     21.00
# 226284        24.0         4.0               NaN       2048.0     24.50
# 227005         4.0         2.0               NaN        707.0      5.00
# 227015        12.0         4.0               NaN        784.0      6.43
#
#         saturated-fat_100g  cholesterol_100g  carbohydrates_100g  sugars_100g  \
# ...

# %% [markdown]
# ## It is better to drop the energy-kcal column because we have energy per 100 g column which is converted to the joule from the energy calorie column only, 1 calorie = 4.186 joule

# %%
df.drop('energy-kcal_100g', axis=1, inplace = True)

# %%
len(df)
# Out:
# 208889

# %%
df.shape
# Out:
# (208889, 12)

# %%
df.sample(10)
# Out:
#         nutriscore  nova_group  energy_100g   fat_100g  saturated-fat_100g  \
# 171413        14.0         4.0        797.0  11.904762            5.952381
# 53452          9.0         3.0       1427.0  25.880000            9.410000
# 196364         9.0         3.0       1594.0   7.140000            1.190000
# 47153         11.0         4.0       1046.0   3.570000            0.000000
# 76042         22.0         4.0       1259.0  25.660000            9.730000
# 137105        14.0         4.0          NaN  30.000000            3.330000
# 78379          0.0         1.0        167.0   4.000000            0.500000
# 176536         9.0         3.0       2092.0  25.000000            3.570000
# 4386          11.0         4.0       1582.0   5.410000            1.350000
# 111846        25.0         4.0       2230.0  36.670000           20.000000
#
#         cholesterol_100g  carbohydrates_100g  sugars_100g  fiber_100g  \
# 171413             0.000           11.904762     4.761905    2.380952
# ...

# %%
df.columns
# Out:
# Index(['nutriscore', 'nova_group', 'energy_100g', 'fat_100g',
#        'saturated-fat_100g', 'cholesterol_100g', 'carbohydrates_100g',
#        'sugars_100g', 'fiber_100g', 'proteins_100g', 'salt_100g',
#        'sodium_100g'],
#       dtype='object')

# %%
df['energy_100g'].fillna(df['energy_100g'].mean(), inplace=True)
df['fat_100g'].fillna(df['fat_100g'].mean(), inplace=True)
df['saturated-fat_100g'].fillna(df['saturated-fat_100g'].mean(), inplace=True)
df['cholesterol_100g'].fillna(df['cholesterol_100g'].mean(), inplace=True)
df['sugars_100g'].fillna(df['sugars_100g'].mean(), inplace=True)
df['fiber_100g'].fillna(df['fiber_100g'].mean(), inplace=True)
df['proteins_100g'].fillna(df['proteins_100g'].mean(), inplace=True)
df['salt_100g'].fillna(df['salt_100g'].mean(), inplace=True)
df['sodium_100g'].fillna(df['sodium_100g'].mean(), inplace=True)
df['carbohydrates_100g'].fillna(df['carbohydrates_100g'].mean(), inplace=True)
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_8624\180321569.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['energy_100g'].fillna(df['energy_100g'].mean(), inplace=True)
# C:\Users\navee\AppData\Local\Temp\ipykernel_8624\180321569.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# nutriscore            0
# nova_group            0
# energy_100g           0
# fat_100g              0
# saturated-fat_100g    0
# cholesterol_100g      0
# carbohydrates_100g    0
# sugars_100g           0
# fiber_100g            0
# proteins_100g         0
# salt_100g             0
# sodium_100g           0
# dtype: int64

# %%
df.dtypes
# Out:
# nutriscore            float64
# nova_group            float64
# energy_100g           float64
# fat_100g              float64
# saturated-fat_100g    float64
# cholesterol_100g      float64
# carbohydrates_100g    float64
# sugars_100g           float64
# fiber_100g            float64
# proteins_100g         float64
# salt_100g             float64
# sodium_100g           float64
# dtype: object

# %% [markdown]
# ## Rename all the columns and remove per 100g from all the column names

# %%
df.columns = [col.replace('_100g', '') for col in df.columns]

# %%
df
# Out:
#         nutriscore  nova_group  energy  fat  saturated-fat  cholesterol  \
# 0             -5.0         1.0   238.0  0.2       0.100000          0.0
# 1             18.0         4.0   936.0  8.2       2.200000          0.0
# 2              9.0         3.0   264.0  0.0       0.000000          0.0
# 3             -4.0         1.0   134.0  0.3       0.100000          0.0
# 5             14.0         4.0   916.0  5.9       0.500000          0.0
# ...            ...         ...     ...  ...            ...          ...
# 227261        13.0         4.0  1197.0  0.0       4.508496          0.0
# 227262        14.0         4.0  1674.0  0.0       4.508496          0.0
# 227263         5.0         2.0  1197.0  0.0       4.508496          0.0
# 227264         5.0         2.0  1197.0  0.0       4.508496          0.0
# 227265        13.0         4.0  1197.0  0.0       0.000000          0.0
#
#         carbohydrates  sugars  fiber  proteins          salt        sodium
# ...

# %%
## save the cleaned data

# %%
df.to_csv("C:/Users/navee/MTP/cleaned_nova_data.csv", index=False)

# %%
cf= pd.read_csv('cleaned_nova_data.csv')

# %%
cf.sample(3)
# Out:
#         nutriscore  nova_group  energy    fat  saturated-fat  cholesterol  \
# 49691         12.0         4.0  2243.0  32.14           5.36         0.00
# 117729        13.0         4.0  1812.0  10.34           0.00         0.00
# 204347        19.0         4.0  1561.0  25.33          16.00         0.02
#
#         carbohydrates  sugars  fiber  proteins    salt  sodium
# 49691           60.71    3.57    3.6      7.14  1.0275   0.411
# 117729          79.31   27.59    3.3      6.90  1.2925   0.517
# 204347          34.67   28.00    2.7      2.67  0.2675   0.107

# %% [markdown]
# ## Arrange all the columns alphabetically

# %%
cf = cf[sorted(cf.columns)]

# %%
cf.sample(3)
# Out:
#         carbohydrates  cholesterol  energy     fat  fiber  proteins    salt  \
# 25497            10.8        0.000   192.0    0.00    0.0     0.833  0.0000
# 96720             0.0        0.000  3586.0  100.00    0.0     0.000  0.0000
# 181173            0.0        0.095  1793.0   33.33    0.0    23.810  1.5119
#
#         saturated-fat   sodium  sugars  nova_group  nutriscore
# 25497            0.00  0.00000    9.17         2.0         4.0
# 96720           14.29  0.00000    0.00         4.0        11.0
# 181173          19.05  0.60476    0.00         4.0        16.0

# %%
# Specify the columns you want at the end
end_columns = ['nova_group', 'nutriscore']

# Get all other columns and sort them
sorted_columns = sorted([col for col in df.columns if col not in end_columns])

# Combine sorted columns with the ones you want at the end
final_columns = sorted_columns + end_columns

# Reorder the DataFrame
cf = cf[final_columns]

# %%
cf.sample(2)
# Out:
#         carbohydrates  cholesterol  energy   fat  fiber  proteins    salt  \
# 4878             4.84       0.0242   269.0  4.03    0.0      1.61  1.4500
# 157286          13.89       0.0000   234.0  0.00    0.0      0.00  0.0375
#
#         saturated-fat  sodium  sugars  nova_group  nutriscore
# 4878             2.42   0.581    1.61         4.0        14.0
# 157286           0.00   0.015   13.89         4.0        18.0
